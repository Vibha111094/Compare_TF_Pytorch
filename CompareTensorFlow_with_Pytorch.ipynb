# %% [markdown]
# <a href="https://colab.research.google.com/github/Vibha111094/Compare_TF_Pytorch/blob/main/CompareTensorFlow_with_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MNIST with tensorflow
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

# %%
type(mnist)
# Out:
# module

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[-0.1917952 ,  0.5079698 ,  0.03809699,  0.03851032, -0.6459373 ,
#         -0.07143611, -0.35055277,  0.00863354,  0.0713068 , -0.7716218 ]],
#       dtype=float32)

# %%
tf.nn.softmax(predictions).numpy()
# Out:
# array([[0.08904951, 0.17928155, 0.11206563, 0.11211196, 0.05654577,
#         0.10043909, 0.07597733, 0.10881195, 0.11584979, 0.04986732]],
#       dtype=float32)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
y_train[:1]
# Out:
# array([5], dtype=uint8)

# %%
loss_fn(y_train[:1], predictions).numpy()
# Out:
# 2.2982037

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2988 - accuracy: 0.9129
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1414 - accuracy: 0.9585
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1077 - accuracy: 0.9671
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0883 - accuracy: 0.9729
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0739 - accuracy: 0.9773

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 0s - loss: 0.0770 - accuracy: 0.9777
# [0.07697781175374985, 0.9776999950408936]

# %%
#MNIST with pytorch

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %%
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print("Shape of X [N, C, H, W]: ", X.shape)
    print("Shape of y: ", y.shape, y.dtype)
    break
# Out:
# Shape of X [N, C, H, W]:  torch.Size([64, 1, 28, 28])
# Shape of y:  torch.Size([64]) torch.int64

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cpu device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 200
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.581344  [    0/60000]
# loss: 1.502355  [ 6400/60000]
# loss: 1.619456  [12800/60000]
# loss: 1.401466  [19200/60000]
# loss: 1.447751  [25600/60000]
# loss: 1.423238  [32000/60000]
# loss: 1.334584  [38400/60000]
# loss: 1.479788  [44800/60000]
# loss: 1.317564  [51200/60000]
# loss: 1.283993  [57600/60000]
# Test Error:
#  Accuracy: 4.0%, Avg loss: 2.599854
#
# Epoch 2
# -------------------------------
# loss: 1.287783  [    0/60000]
# loss: 1.177848  [ 6400/60000]
# loss: 1.297299  [12800/60000]
# loss: 1.109206  [19200/60000]
# loss: 1.137068  [25600/60000]
# loss: 1.114177  [32000/60000]
# loss: 1.041664  [38400/60000]
# loss: 1.205503  [44800/60000]
# loss: 1.067109  [51200/60000]
# loss: 1.024036  [57600/60000]
# Test Error:
#  Accuracy: 6.3%, Avg loss: 2.874487
#
# Epoch 3
# -------------------------------
# loss: 1.062763  [    0/60000]
# loss: 0.939427  [ 6400/60000]
# loss: 1.040841  [12800/60000]
# loss: 0.905389  [19200/60000]
# loss: 0.917220  [25600/60000]
# loss: 0.897938  [32000/60000]
# loss: 0.836692  [38400/60000]
# loss: 1.003152  [44800/60000]
# loss: 0.899463  [51200/60000]
# loss: 0.853303  [57600/60000]
# Test Error:
#  Accuracy: 6.7%, Avg loss: 3.201916
#
# Epoch 4
# -------------------------------
# loss: 0.910683  [    0/60000]
# loss: 0.783158  [ 6400/60000]
# loss: 0.865041  [12800/60000]
# loss: 0.774451  [19200/60000]
# loss: 0.774032  [25600/60000]
# loss: 0.756651  [32000/60000]
# loss: 0.698734  [38400/60000]
# loss: 0.863076  [44800/60000]
# loss: 0.787776  [51200/60000]
# loss: 0.745078  [57600/60000]
# Test Error:
#  Accuracy: 6.4%, Avg loss: 3.523037
#
# Epoch 5
# -------------------------------
# loss: 0.806048  [    0/60000]
# loss: 0.676874  [ 6400/60000]
# loss: 0.744936  [12800/60000]
# loss: 0.687972  [19200/60000]
# loss: 0.676741  [25600/60000]
# loss: 0.661898  [32000/60000]
# loss: 0.601961  [38400/60000]
# loss: 0.765532  [44800/60000]
# loss: 0.708493  [51200/60000]
# loss: 0.673810  [57600/60000]
# Test Error:
#  Accuracy: 6.3%, Avg loss: 3.815739
#
# Epoch 6
# -------------------------------
# loss: 0.730584  [    0/60000]
# loss: 0.600189  [ 6400/60000]
# loss: 0.659731  [12800/60000]
# loss: 0.627873  [19200/60000]
# loss: 0.606559  [25600/60000]
# loss: 0.596035  [32000/60000]
# loss: 0.531182  [38400/60000]
# loss: 0.696159  [44800/60000]
# loss: 0.649213  [51200/60000]
# loss: 0.624706  [57600/60000]
# Test Error:
#  Accuracy: 6.4%, Avg loss: 4.075996
#
# Epoch 7
# -------------------------------
# loss: 0.673497  [    0/60000]
# loss: 0.542325  [ 6400/60000]
# loss: 0.596584  [12800/60000]
# loss: 0.584098  [19200/60000]
# loss: 0.553523  [25600/60000]
# loss: 0.548754  [32000/60000]
# loss: 0.477649  [38400/60000]
# loss: 0.645632  [44800/60000]
# loss: 0.603388  [51200/60000]
# loss: 0.589682  [57600/60000]
# Test Error:
#  Accuracy: 6.7%, Avg loss: 4.306124
#
# Epoch 8
# -------------------------------
# loss: 0.628318  [    0/60000]
# loss: 0.497443  [ 6400/60000]
# loss: 0.547984  [12800/60000]
# loss: 0.550896  [19200/60000]
# loss: 0.511913  [25600/60000]
# loss: 0.513765  [32000/60000]
# loss: 0.436143  [38400/60000]
# loss: 0.607655  [44800/60000]
# loss: 0.567066  [51200/60000]
# loss: 0.563857  [57600/60000]
# Test Error:
#  Accuracy: 7.0%, Avg loss: 4.510357
#
# Epoch 9
# -------------------------------
# loss: 0.591351  [    0/60000]
# loss: 0.461852  [ 6400/60000]
# loss: 0.509427  [12800/60000]
# loss: 0.524915  [19200/60000]
# loss: 0.478315  [25600/60000]
# loss: 0.487161  [32000/60000]
# loss: 0.403250  [38400/60000]
# loss: 0.578289  [44800/60000]
# loss: 0.537702  [51200/60000]
# loss: 0.544282  [57600/60000]
# Test Error:
#  Accuracy: 7.3%, Avg loss: 4.692653
#
# Epoch 10
# -------------------------------
# loss: 0.560221  [    0/60000]
# loss: 0.433161  [ 6400/60000]
# loss: 0.477968  [12800/60000]
# loss: 0.504062  [19200/60000]
# loss: 0.450600  [25600/60000]
# loss: 0.466504  [32000/60000]
# loss: 0.376680  [38400/60000]
# loss: 0.554893  [44800/60000]
# loss: 0.513478  [51200/60000]
# loss: 0.528944  [57600/60000]
# Test Error:
#  Accuracy: 7.6%, Avg loss: 4.856624
#
# Epoch 11
# -------------------------------
# loss: 0.533380  [    0/60000]
# loss: 0.409756  [ 6400/60000]
# loss: 0.451667  [12800/60000]
# loss: 0.486916  [19200/60000]
# loss: 0.427264  [25600/60000]
# loss: 0.450082  [32000/60000]
# loss: 0.354786  [38400/60000]
# loss: 0.535791  [44800/60000]
# loss: 0.493222  [51200/60000]
# loss: 0.516587  [57600/60000]
# Test Error:
#  Accuracy: 7.8%, Avg loss: 5.005083
#
# Epoch 12
# -------------------------------
# loss: 0.509838  [    0/60000]
# loss: 0.390469  [ 6400/60000]
# loss: 0.429158  [12800/60000]
# loss: 0.472509  [19200/60000]
# loss: 0.407351  [25600/60000]
# loss: 0.436646  [32000/60000]
# loss: 0.336469  [38400/60000]
# loss: 0.519864  [44800/60000]
# loss: 0.476065  [51200/60000]
# loss: 0.506421  [57600/60000]
# Test Error:
#  Accuracy: 8.0%, Avg loss: 5.140249
#
# Epoch 13
# -------------------------------
# loss: 0.488907  [    0/60000]
# loss: 0.374484  [ 6400/60000]
# loss: 0.409538  [12800/60000]
# loss: 0.460202  [19200/60000]
# loss: 0.390166  [25600/60000]
# loss: 0.425411  [32000/60000]
# loss: 0.320917  [38400/60000]
# loss: 0.506308  [44800/60000]
# loss: 0.461298  [51200/60000]
# loss: 0.497843  [57600/60000]
# Test Error:
#  Accuracy: 8.2%, Avg loss: 5.263788
#
# Epoch 14
# -------------------------------
# loss: 0.470095  [    0/60000]
# loss: 0.361134  [ 6400/60000]
# loss: 0.392205  [12800/60000]
# loss: 0.449540  [19200/60000]
# loss: 0.375201  [25600/60000]
# loss: 0.415795  [32000/60000]
# loss: 0.307511  [38400/60000]
# loss: 0.494618  [44800/60000]
# loss: 0.448420  [51200/60000]
# loss: 0.490477  [57600/60000]
# Test Error:
#  Accuracy: 8.5%, Avg loss: 5.377543
#
# Epoch 15
# -------------------------------
# loss: 0.453011  [    0/60000]
# loss: 0.349908  [ 6400/60000]
# loss: 0.376715  [12800/60000]
# loss: 0.440121  [19200/60000]
# loss: 0.362067  [25600/60000]
# loss: 0.407363  [32000/60000]
# loss: 0.295818  [38400/60000]
# loss: 0.484312  [44800/60000]
# loss: 0.437038  [51200/60000]
# loss: 0.484016  [57600/60000]
# Test Error:
#  Accuracy: 8.6%, Avg loss: 5.482830
#
# Epoch 16
# -------------------------------
# loss: 0.437433  [    0/60000]
# loss: 0.340400  [ 6400/60000]
# loss: 0.362742  [12800/60000]
# loss: 0.431735  [19200/60000]
# loss: 0.350442  [25600/60000]
# loss: 0.399854  [32000/60000]
# loss: 0.285524  [38400/60000]
# loss: 0.475067  [44800/60000]
# loss: 0.426842  [51200/60000]
# loss: 0.478308  [57600/60000]
# Test Error:
#  Accuracy: 8.8%, Avg loss: 5.580642
#
# Epoch 17
# -------------------------------
# loss: 0.423142  [    0/60000]
# loss: 0.332264  [ 6400/60000]
# loss: 0.350061  [12800/60000]
# loss: 0.424222  [19200/60000]
# loss: 0.340098  [25600/60000]
# loss: 0.393087  [32000/60000]
# loss: 0.276348  [38400/60000]
# loss: 0.466712  [44800/60000]
# loss: 0.417619  [51200/60000]
# loss: 0.473228  [57600/60000]
# Test Error:
#  Accuracy: 8.8%, Avg loss: 5.672009
#
# Epoch 18
# -------------------------------
# loss: 0.410029  [    0/60000]
# loss: 0.325312  [ 6400/60000]
# loss: 0.338465  [12800/60000]
# loss: 0.417427  [19200/60000]
# loss: 0.330810  [25600/60000]
# loss: 0.386908  [32000/60000]
# loss: 0.268160  [38400/60000]
# loss: 0.459147  [44800/60000]
# loss: 0.409282  [51200/60000]
# loss: 0.468544  [57600/60000]
# Test Error:
#  Accuracy: 8.8%, Avg loss: 5.757718
#
# Epoch 19
# -------------------------------
# loss: 0.397893  [    0/60000]
# loss: 0.319247  [ 6400/60000]
# loss: 0.327817  [12800/60000]
# loss: 0.411283  [19200/60000]
# loss: 0.322450  [25600/60000]
# loss: 0.381234  [32000/60000]
# loss: 0.260806  [38400/60000]
# loss: 0.452186  [44800/60000]
# loss: 0.401626  [51200/60000]
# loss: 0.464177  [57600/60000]
# Test Error:
#  Accuracy: 9.0%, Avg loss: 5.838375
#
# Epoch 20
# -------------------------------
# loss: 0.386609  [    0/60000]
# loss: 0.313961  [ 6400/60000]
# loss: 0.317963  [12800/60000]
# loss: 0.405683  [19200/60000]
# loss: 0.314904  [25600/60000]
# loss: 0.375969  [32000/60000]
# loss: 0.254211  [38400/60000]
# loss: 0.445754  [44800/60000]
# loss: 0.394531  [51200/60000]
# loss: 0.460146  [57600/60000]
# Test Error:
#  Accuracy: 9.1%, Avg loss: 5.914497
#
# Epoch 21
# -------------------------------
# loss: 0.376108  [    0/60000]
# loss: 0.309305  [ 6400/60000]
# loss: 0.308807  [12800/60000]
# loss: 0.400452  [19200/60000]
# loss: 0.307989  [25600/60000]
# loss: 0.371064  [32000/60000]
# loss: 0.248219  [38400/60000]
# loss: 0.439756  [44800/60000]
# loss: 0.387939  [51200/60000]
# loss: 0.456412  [57600/60000]
# Test Error:
#  Accuracy: 9.3%, Avg loss: 5.986526
#
# Epoch 22
# -------------------------------
# loss: 0.366278  [    0/60000]
# loss: 0.305192  [ 6400/60000]
# loss: 0.300326  [12800/60000]
# loss: 0.395557  [19200/60000]
# loss: 0.301633  [25600/60000]
# loss: 0.366453  [32000/60000]
# loss: 0.242790  [38400/60000]
# loss: 0.434153  [44800/60000]
# loss: 0.381786  [51200/60000]
# loss: 0.452913  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 6.054990
#
# Epoch 23
# -------------------------------
# loss: 0.357073  [    0/60000]
# loss: 0.301504  [ 6400/60000]
# loss: 0.292431  [12800/60000]
# loss: 0.390987  [19200/60000]
# loss: 0.295747  [25600/60000]
# loss: 0.362144  [32000/60000]
# loss: 0.237796  [38400/60000]
# loss: 0.428905  [44800/60000]
# loss: 0.375914  [51200/60000]
# loss: 0.449572  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 6.120189
#
# Epoch 24
# -------------------------------
# loss: 0.348403  [    0/60000]
# loss: 0.298112  [ 6400/60000]
# loss: 0.285070  [12800/60000]
# loss: 0.386739  [19200/60000]
# loss: 0.290275  [25600/60000]
# loss: 0.358095  [32000/60000]
# loss: 0.233250  [38400/60000]
# loss: 0.423942  [44800/60000]
# loss: 0.370308  [51200/60000]
# loss: 0.446334  [57600/60000]
# Test Error:
#  Accuracy: 9.7%, Avg loss: 6.182174
#
# Epoch 25
# -------------------------------
# loss: 0.340222  [    0/60000]
# loss: 0.295009  [ 6400/60000]
# loss: 0.278183  [12800/60000]
# loss: 0.382768  [19200/60000]
# loss: 0.285173  [25600/60000]
# loss: 0.354258  [32000/60000]
# loss: 0.229054  [38400/60000]
# loss: 0.419284  [44800/60000]
# loss: 0.365024  [51200/60000]
# loss: 0.443223  [57600/60000]
# Test Error:
#  Accuracy: 9.8%, Avg loss: 6.241455
#
# Epoch 26
# -------------------------------
# loss: 0.332478  [    0/60000]
# loss: 0.292123  [ 6400/60000]
# loss: 0.271713  [12800/60000]
# loss: 0.379037  [19200/60000]
# loss: 0.280388  [25600/60000]
# loss: 0.350666  [32000/60000]
# loss: 0.225174  [38400/60000]
# loss: 0.414907  [44800/60000]
# loss: 0.360060  [51200/60000]
# loss: 0.440252  [57600/60000]
# Test Error:
#  Accuracy: 9.9%, Avg loss: 6.298094
#
# Epoch 27
# -------------------------------
# loss: 0.325127  [    0/60000]
# loss: 0.289462  [ 6400/60000]
# loss: 0.265616  [12800/60000]
# loss: 0.375483  [19200/60000]
# loss: 0.275859  [25600/60000]
# loss: 0.347312  [32000/60000]
# loss: 0.221586  [38400/60000]
# loss: 0.410708  [44800/60000]
# loss: 0.355335  [51200/60000]
# loss: 0.437397  [57600/60000]
# Test Error:
#  Accuracy: 10.0%, Avg loss: 6.352239
#
# Epoch 28
# -------------------------------
# loss: 0.318119  [    0/60000]
# loss: 0.287015  [ 6400/60000]
# loss: 0.259836  [12800/60000]
# loss: 0.372088  [19200/60000]
# loss: 0.271551  [25600/60000]
# loss: 0.344151  [32000/60000]
# loss: 0.218287  [38400/60000]
# loss: 0.406674  [44800/60000]
# loss: 0.350764  [51200/60000]
# loss: 0.434596  [57600/60000]
# Test Error:
#  Accuracy: 10.1%, Avg loss: 6.404495
#
# Epoch 29
# -------------------------------
# loss: 0.311447  [    0/60000]
# loss: 0.284737  [ 6400/60000]
# loss: 0.254405  [12800/60000]
# loss: 0.368871  [19200/60000]
# loss: 0.267451  [25600/60000]
# loss: 0.341066  [32000/60000]
# loss: 0.215216  [38400/60000]
# loss: 0.402830  [44800/60000]
# loss: 0.346360  [51200/60000]
# loss: 0.431824  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 6.454500
#
# Epoch 30
# -------------------------------
# loss: 0.305017  [    0/60000]
# loss: 0.282543  [ 6400/60000]
# loss: 0.249262  [12800/60000]
# loss: 0.365810  [19200/60000]
# loss: 0.263564  [25600/60000]
# loss: 0.338071  [32000/60000]
# loss: 0.212373  [38400/60000]
# loss: 0.399112  [44800/60000]
# loss: 0.342107  [51200/60000]
# loss: 0.429028  [57600/60000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 6.502539
#
# Epoch 31
# -------------------------------
# loss: 0.298882  [    0/60000]
# loss: 0.280474  [ 6400/60000]
# loss: 0.244397  [12800/60000]
# loss: 0.362840  [19200/60000]
# loss: 0.259854  [25600/60000]
# loss: 0.335177  [32000/60000]
# loss: 0.209684  [38400/60000]
# loss: 0.395541  [44800/60000]
# loss: 0.337997  [51200/60000]
# loss: 0.426253  [57600/60000]
# Test Error:
#  Accuracy: 10.4%, Avg loss: 6.548869
#
# Epoch 32
# -------------------------------
# loss: 0.292990  [    0/60000]
# loss: 0.278526  [ 6400/60000]
# loss: 0.239810  [12800/60000]
# loss: 0.360038  [19200/60000]
# loss: 0.256295  [25600/60000]
# loss: 0.332409  [32000/60000]
# loss: 0.207153  [38400/60000]
# loss: 0.392144  [44800/60000]
# loss: 0.333991  [51200/60000]
# loss: 0.423444  [57600/60000]
# Test Error:
#  Accuracy: 10.5%, Avg loss: 6.593566
#
# Epoch 33
# -------------------------------
# loss: 0.287340  [    0/60000]
# loss: 0.276686  [ 6400/60000]
# loss: 0.235442  [12800/60000]
# loss: 0.357345  [19200/60000]
# loss: 0.252888  [25600/60000]
# loss: 0.329736  [32000/60000]
# loss: 0.204743  [38400/60000]
# loss: 0.388905  [44800/60000]
# loss: 0.330088  [51200/60000]
# loss: 0.420678  [57600/60000]
# Test Error:
#  Accuracy: 10.6%, Avg loss: 6.636863
#
# Epoch 34
# -------------------------------
# loss: 0.281908  [    0/60000]
# loss: 0.274886  [ 6400/60000]
# loss: 0.231313  [12800/60000]
# loss: 0.354715  [19200/60000]
# loss: 0.249618  [25600/60000]
# loss: 0.327154  [32000/60000]
# loss: 0.202450  [38400/60000]
# loss: 0.385867  [44800/60000]
# loss: 0.326302  [51200/60000]
# loss: 0.417891  [57600/60000]
# Test Error:
#  Accuracy: 10.7%, Avg loss: 6.679035
#
# Epoch 35
# -------------------------------
# loss: 0.276716  [    0/60000]
# loss: 0.273150  [ 6400/60000]
# loss: 0.227369  [12800/60000]
# loss: 0.352183  [19200/60000]
# loss: 0.246444  [25600/60000]
# loss: 0.324656  [32000/60000]
# loss: 0.200214  [38400/60000]
# loss: 0.383002  [44800/60000]
# loss: 0.322556  [51200/60000]
# loss: 0.415146  [57600/60000]
# Test Error:
#  Accuracy: 10.7%, Avg loss: 6.719600
#
# Epoch 36
# -------------------------------
# loss: 0.271715  [    0/60000]
# loss: 0.271439  [ 6400/60000]
# loss: 0.223621  [12800/60000]
# loss: 0.349722  [19200/60000]
# loss: 0.243370  [25600/60000]
# loss: 0.322240  [32000/60000]
# loss: 0.198103  [38400/60000]
# loss: 0.380252  [44800/60000]
# loss: 0.318878  [51200/60000]
# loss: 0.412398  [57600/60000]
# Test Error:
#  Accuracy: 10.8%, Avg loss: 6.758790
#
# Epoch 37
# -------------------------------
# loss: 0.266912  [    0/60000]
# loss: 0.269809  [ 6400/60000]
# loss: 0.220070  [12800/60000]
# loss: 0.347357  [19200/60000]
# loss: 0.240381  [25600/60000]
# loss: 0.319884  [32000/60000]
# loss: 0.196047  [38400/60000]
# loss: 0.377599  [44800/60000]
# loss: 0.315285  [51200/60000]
# loss: 0.409694  [57600/60000]
# Test Error:
#  Accuracy: 10.9%, Avg loss: 6.796542
#
# Epoch 38
# -------------------------------
# loss: 0.262291  [    0/60000]
# loss: 0.268204  [ 6400/60000]
# loss: 0.216685  [12800/60000]
# loss: 0.345003  [19200/60000]
# loss: 0.237482  [25600/60000]
# loss: 0.317620  [32000/60000]
# loss: 0.194050  [38400/60000]
# loss: 0.375046  [44800/60000]
# loss: 0.311749  [51200/60000]
# loss: 0.407050  [57600/60000]
# Test Error:
#  Accuracy: 10.9%, Avg loss: 6.832984
#
# Epoch 39
# -------------------------------
# loss: 0.257821  [    0/60000]
# loss: 0.266662  [ 6400/60000]
# loss: 0.213457  [12800/60000]
# loss: 0.342661  [19200/60000]
# loss: 0.234651  [25600/60000]
# loss: 0.315438  [32000/60000]
# loss: 0.192072  [38400/60000]
# loss: 0.372551  [44800/60000]
# loss: 0.308307  [51200/60000]
# loss: 0.404453  [57600/60000]
# Test Error:
#  Accuracy: 11.1%, Avg loss: 6.868698
#
# Epoch 40
# -------------------------------
# loss: 0.253509  [    0/60000]
# loss: 0.265141  [ 6400/60000]
# loss: 0.210327  [12800/60000]
# loss: 0.340409  [19200/60000]
# loss: 0.231865  [25600/60000]
# loss: 0.313296  [32000/60000]
# loss: 0.190106  [38400/60000]
# loss: 0.370114  [44800/60000]
# loss: 0.304880  [51200/60000]
# loss: 0.401889  [57600/60000]
# Test Error:
#  Accuracy: 11.1%, Avg loss: 6.903052
#
# Epoch 41
# -------------------------------
# loss: 0.249371  [    0/60000]
# loss: 0.263643  [ 6400/60000]
# loss: 0.207303  [12800/60000]
# loss: 0.338288  [19200/60000]
# loss: 0.229139  [25600/60000]
# loss: 0.311202  [32000/60000]
# loss: 0.188221  [38400/60000]
# loss: 0.367697  [44800/60000]
# loss: 0.301512  [51200/60000]
# loss: 0.399331  [57600/60000]
# Test Error:
#  Accuracy: 11.2%, Avg loss: 6.936521
#
# Epoch 42
# -------------------------------
# loss: 0.245349  [    0/60000]
# loss: 0.262229  [ 6400/60000]
# loss: 0.204378  [12800/60000]
# loss: 0.336219  [19200/60000]
# loss: 0.226483  [25600/60000]
# loss: 0.309144  [32000/60000]
# loss: 0.186388  [38400/60000]
# loss: 0.365337  [44800/60000]
# loss: 0.298264  [51200/60000]
# loss: 0.396749  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 6.969172
#
# Epoch 43
# -------------------------------
# loss: 0.241453  [    0/60000]
# loss: 0.260845  [ 6400/60000]
# loss: 0.201619  [12800/60000]
# loss: 0.334170  [19200/60000]
# loss: 0.223855  [25600/60000]
# loss: 0.307152  [32000/60000]
# loss: 0.184612  [38400/60000]
# loss: 0.363021  [44800/60000]
# loss: 0.295075  [51200/60000]
# loss: 0.394248  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.000819
#
# Epoch 44
# -------------------------------
# loss: 0.237658  [    0/60000]
# loss: 0.259428  [ 6400/60000]
# loss: 0.198968  [12800/60000]
# loss: 0.332209  [19200/60000]
# loss: 0.221315  [25600/60000]
# loss: 0.305166  [32000/60000]
# loss: 0.182883  [38400/60000]
# loss: 0.360798  [44800/60000]
# loss: 0.291941  [51200/60000]
# loss: 0.391750  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.031766
#
# Epoch 45
# -------------------------------
# loss: 0.233973  [    0/60000]
# loss: 0.257981  [ 6400/60000]
# loss: 0.196429  [12800/60000]
# loss: 0.330265  [19200/60000]
# loss: 0.218848  [25600/60000]
# loss: 0.303166  [32000/60000]
# loss: 0.181191  [38400/60000]
# loss: 0.358641  [44800/60000]
# loss: 0.288837  [51200/60000]
# loss: 0.389230  [57600/60000]
# Test Error:
#  Accuracy: 11.4%, Avg loss: 7.062029
#
# Epoch 46
# -------------------------------
# loss: 0.230406  [    0/60000]
# loss: 0.256566  [ 6400/60000]
# loss: 0.193981  [12800/60000]
# loss: 0.328377  [19200/60000]
# loss: 0.216435  [25600/60000]
# loss: 0.301235  [32000/60000]
# loss: 0.179515  [38400/60000]
# loss: 0.356508  [44800/60000]
# loss: 0.285738  [51200/60000]
# loss: 0.386698  [57600/60000]
# Test Error:
#  Accuracy: 11.5%, Avg loss: 7.091632
#
# Epoch 47
# -------------------------------
# loss: 0.226940  [    0/60000]
# loss: 0.255128  [ 6400/60000]
# loss: 0.191595  [12800/60000]
# loss: 0.326506  [19200/60000]
# loss: 0.214058  [25600/60000]
# loss: 0.299304  [32000/60000]
# loss: 0.177869  [38400/60000]
# loss: 0.354436  [44800/60000]
# loss: 0.282672  [51200/60000]
# loss: 0.384162  [57600/60000]
# Test Error:
#  Accuracy: 11.5%, Avg loss: 7.120682
#
# Epoch 48
# -------------------------------
# loss: 0.223585  [    0/60000]
# loss: 0.253719  [ 6400/60000]
# loss: 0.189270  [12800/60000]
# loss: 0.324654  [19200/60000]
# loss: 0.211774  [25600/60000]
# loss: 0.297398  [32000/60000]
# loss: 0.176270  [38400/60000]
# loss: 0.352427  [44800/60000]
# loss: 0.279653  [51200/60000]
# loss: 0.381610  [57600/60000]
# Test Error:
#  Accuracy: 11.4%, Avg loss: 7.149221
#
# Epoch 49
# -------------------------------
# loss: 0.220345  [    0/60000]
# loss: 0.252315  [ 6400/60000]
# loss: 0.187009  [12800/60000]
# loss: 0.322785  [19200/60000]
# loss: 0.209568  [25600/60000]
# loss: 0.295489  [32000/60000]
# loss: 0.174720  [38400/60000]
# loss: 0.350486  [44800/60000]
# loss: 0.276594  [51200/60000]
# loss: 0.379058  [57600/60000]
# Test Error:
#  Accuracy: 11.4%, Avg loss: 7.177135
#
# Epoch 50
# -------------------------------
# loss: 0.217198  [    0/60000]
# loss: 0.250928  [ 6400/60000]
# loss: 0.184815  [12800/60000]
# loss: 0.320902  [19200/60000]
# loss: 0.207437  [25600/60000]
# loss: 0.293637  [32000/60000]
# loss: 0.173192  [38400/60000]
# loss: 0.348536  [44800/60000]
# loss: 0.273586  [51200/60000]
# loss: 0.376545  [57600/60000]
# Test Error:
#  Accuracy: 11.4%, Avg loss: 7.204650
#
# Epoch 51
# -------------------------------
# loss: 0.214158  [    0/60000]
# loss: 0.249507  [ 6400/60000]
# loss: 0.182721  [12800/60000]
# loss: 0.319038  [19200/60000]
# loss: 0.205332  [25600/60000]
# loss: 0.291769  [32000/60000]
# loss: 0.171710  [38400/60000]
# loss: 0.346533  [44800/60000]
# loss: 0.270583  [51200/60000]
# loss: 0.374067  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.231873
#
# Epoch 52
# -------------------------------
# loss: 0.211193  [    0/60000]
# loss: 0.248090  [ 6400/60000]
# loss: 0.180703  [12800/60000]
# loss: 0.317205  [19200/60000]
# loss: 0.203301  [25600/60000]
# loss: 0.289867  [32000/60000]
# loss: 0.170271  [38400/60000]
# loss: 0.344556  [44800/60000]
# loss: 0.267654  [51200/60000]
# loss: 0.371627  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.258580
#
# Epoch 53
# -------------------------------
# loss: 0.208288  [    0/60000]
# loss: 0.246718  [ 6400/60000]
# loss: 0.178734  [12800/60000]
# loss: 0.315352  [19200/60000]
# loss: 0.201324  [25600/60000]
# loss: 0.288005  [32000/60000]
# loss: 0.168856  [38400/60000]
# loss: 0.342606  [44800/60000]
# loss: 0.264813  [51200/60000]
# loss: 0.369159  [57600/60000]
# Test Error:
#  Accuracy: 11.4%, Avg loss: 7.284975
#
# Epoch 54
# -------------------------------
# loss: 0.205477  [    0/60000]
# loss: 0.245387  [ 6400/60000]
# loss: 0.176835  [12800/60000]
# loss: 0.313495  [19200/60000]
# loss: 0.199392  [25600/60000]
# loss: 0.286180  [32000/60000]
# loss: 0.167485  [38400/60000]
# loss: 0.340723  [44800/60000]
# loss: 0.262041  [51200/60000]
# loss: 0.366691  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.311113
#
# Epoch 55
# -------------------------------
# loss: 0.202772  [    0/60000]
# loss: 0.244083  [ 6400/60000]
# loss: 0.174975  [12800/60000]
# loss: 0.311678  [19200/60000]
# loss: 0.197471  [25600/60000]
# loss: 0.284353  [32000/60000]
# loss: 0.166147  [38400/60000]
# loss: 0.338836  [44800/60000]
# loss: 0.259332  [51200/60000]
# loss: 0.364296  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.336621
#
# Epoch 56
# -------------------------------
# loss: 0.200103  [    0/60000]
# loss: 0.242769  [ 6400/60000]
# loss: 0.173160  [12800/60000]
# loss: 0.309872  [19200/60000]
# loss: 0.195546  [25600/60000]
# loss: 0.282540  [32000/60000]
# loss: 0.164807  [38400/60000]
# loss: 0.336953  [44800/60000]
# loss: 0.256637  [51200/60000]
# loss: 0.361873  [57600/60000]
# Test Error:
#  Accuracy: 11.4%, Avg loss: 7.361737
#
# Epoch 57
# -------------------------------
# loss: 0.197505  [    0/60000]
# loss: 0.241478  [ 6400/60000]
# loss: 0.171405  [12800/60000]
# loss: 0.308032  [19200/60000]
# loss: 0.193684  [25600/60000]
# loss: 0.280782  [32000/60000]
# loss: 0.163479  [38400/60000]
# loss: 0.335123  [44800/60000]
# loss: 0.253999  [51200/60000]
# loss: 0.359437  [57600/60000]
# Test Error:
#  Accuracy: 11.4%, Avg loss: 7.386752
#
# Epoch 58
# -------------------------------
# loss: 0.194983  [    0/60000]
# loss: 0.240208  [ 6400/60000]
# loss: 0.169685  [12800/60000]
# loss: 0.306217  [19200/60000]
# loss: 0.191914  [25600/60000]
# loss: 0.279124  [32000/60000]
# loss: 0.162176  [38400/60000]
# loss: 0.333373  [44800/60000]
# loss: 0.251393  [51200/60000]
# loss: 0.357042  [57600/60000]
# Test Error:
#  Accuracy: 11.4%, Avg loss: 7.411565
#
# Epoch 59
# -------------------------------
# loss: 0.192539  [    0/60000]
# loss: 0.238941  [ 6400/60000]
# loss: 0.168002  [12800/60000]
# loss: 0.304377  [19200/60000]
# loss: 0.190202  [25600/60000]
# loss: 0.277390  [32000/60000]
# loss: 0.160889  [38400/60000]
# loss: 0.331666  [44800/60000]
# loss: 0.248832  [51200/60000]
# loss: 0.354651  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.435901
#
# Epoch 60
# -------------------------------
# loss: 0.190138  [    0/60000]
# loss: 0.237640  [ 6400/60000]
# loss: 0.166338  [12800/60000]
# loss: 0.302520  [19200/60000]
# loss: 0.188534  [25600/60000]
# loss: 0.275677  [32000/60000]
# loss: 0.159607  [38400/60000]
# loss: 0.329978  [44800/60000]
# loss: 0.246360  [51200/60000]
# loss: 0.352279  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.459851
#
# Epoch 61
# -------------------------------
# loss: 0.187795  [    0/60000]
# loss: 0.236319  [ 6400/60000]
# loss: 0.164707  [12800/60000]
# loss: 0.300695  [19200/60000]
# loss: 0.186899  [25600/60000]
# loss: 0.274140  [32000/60000]
# loss: 0.158349  [38400/60000]
# loss: 0.328286  [44800/60000]
# loss: 0.243932  [51200/60000]
# loss: 0.349906  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.482765
#
# Epoch 62
# -------------------------------
# loss: 0.185505  [    0/60000]
# loss: 0.235010  [ 6400/60000]
# loss: 0.163130  [12800/60000]
# loss: 0.298911  [19200/60000]
# loss: 0.185318  [25600/60000]
# loss: 0.272659  [32000/60000]
# loss: 0.157057  [38400/60000]
# loss: 0.326662  [44800/60000]
# loss: 0.241571  [51200/60000]
# loss: 0.347504  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.505421
#
# Epoch 63
# -------------------------------
# loss: 0.183247  [    0/60000]
# loss: 0.233735  [ 6400/60000]
# loss: 0.161572  [12800/60000]
# loss: 0.297135  [19200/60000]
# loss: 0.183738  [25600/60000]
# loss: 0.271214  [32000/60000]
# loss: 0.155776  [38400/60000]
# loss: 0.325057  [44800/60000]
# loss: 0.239262  [51200/60000]
# loss: 0.345107  [57600/60000]
# Test Error:
#  Accuracy: 11.3%, Avg loss: 7.527592
#
# Epoch 64
# -------------------------------
# loss: 0.181049  [    0/60000]
# loss: 0.232473  [ 6400/60000]
# loss: 0.160082  [12800/60000]
# loss: 0.295308  [19200/60000]
# loss: 0.182176  [25600/60000]
# loss: 0.269763  [32000/60000]
# loss: 0.154520  [38400/60000]
# loss: 0.323440  [44800/60000]
# loss: 0.236969  [51200/60000]
# loss: 0.342773  [57600/60000]
# Test Error:
#  Accuracy: 11.2%, Avg loss: 7.549403
#
# Epoch 65
# -------------------------------
# loss: 0.178909  [    0/60000]
# loss: 0.231253  [ 6400/60000]
# loss: 0.158674  [12800/60000]
# loss: 0.293505  [19200/60000]
# loss: 0.180643  [25600/60000]
# loss: 0.268337  [32000/60000]
# loss: 0.153248  [38400/60000]
# loss: 0.321858  [44800/60000]
# loss: 0.234658  [51200/60000]
# loss: 0.340411  [57600/60000]
# Test Error:
#  Accuracy: 11.2%, Avg loss: 7.571351
#
# Epoch 66
# -------------------------------
# loss: 0.176809  [    0/60000]
# loss: 0.230084  [ 6400/60000]
# loss: 0.157305  [12800/60000]
# loss: 0.291705  [19200/60000]
# loss: 0.179154  [25600/60000]
# loss: 0.266966  [32000/60000]
# loss: 0.151990  [38400/60000]
# loss: 0.320322  [44800/60000]
# loss: 0.232371  [51200/60000]
# loss: 0.338066  [57600/60000]
# Test Error:
#  Accuracy: 11.1%, Avg loss: 7.592693
#
# Epoch 67
# -------------------------------
# loss: 0.174737  [    0/60000]
# loss: 0.228977  [ 6400/60000]
# loss: 0.155959  [12800/60000]
# loss: 0.289953  [19200/60000]
# loss: 0.177672  [25600/60000]
# loss: 0.265605  [32000/60000]
# loss: 0.150742  [38400/60000]
# loss: 0.318775  [44800/60000]
# loss: 0.230112  [51200/60000]
# loss: 0.335720  [57600/60000]
# Test Error:
#  Accuracy: 11.0%, Avg loss: 7.613605
#
# Epoch 68
# -------------------------------
# loss: 0.172679  [    0/60000]
# loss: 0.227877  [ 6400/60000]
# loss: 0.154639  [12800/60000]
# loss: 0.288195  [19200/60000]
# loss: 0.176238  [25600/60000]
# loss: 0.264272  [32000/60000]
# loss: 0.149521  [38400/60000]
# loss: 0.317229  [44800/60000]
# loss: 0.227864  [51200/60000]
# loss: 0.333417  [57600/60000]
# Test Error:
#  Accuracy: 11.0%, Avg loss: 7.634316
#
# Epoch 69
# -------------------------------
# loss: 0.170654  [    0/60000]
# loss: 0.226831  [ 6400/60000]
# loss: 0.153326  [12800/60000]
# loss: 0.286441  [19200/60000]
# loss: 0.174813  [25600/60000]
# loss: 0.262909  [32000/60000]
# loss: 0.148300  [38400/60000]
# loss: 0.315636  [44800/60000]
# loss: 0.225591  [51200/60000]
# loss: 0.331115  [57600/60000]
# Test Error:
#  Accuracy: 11.0%, Avg loss: 7.655122
#
# Epoch 70
# -------------------------------
# loss: 0.168673  [    0/60000]
# loss: 0.225746  [ 6400/60000]
# loss: 0.152040  [12800/60000]
# loss: 0.284677  [19200/60000]
# loss: 0.173414  [25600/60000]
# loss: 0.261597  [32000/60000]
# loss: 0.147080  [38400/60000]
# loss: 0.314032  [44800/60000]
# loss: 0.223356  [51200/60000]
# loss: 0.328830  [57600/60000]
# Test Error:
#  Accuracy: 10.9%, Avg loss: 7.675708
#
# Epoch 71
# -------------------------------
# loss: 0.166739  [    0/60000]
# loss: 0.224681  [ 6400/60000]
# loss: 0.150788  [12800/60000]
# loss: 0.282910  [19200/60000]
# loss: 0.172077  [25600/60000]
# loss: 0.260329  [32000/60000]
# loss: 0.145871  [38400/60000]
# loss: 0.312442  [44800/60000]
# loss: 0.221170  [51200/60000]
# loss: 0.326573  [57600/60000]
# Test Error:
#  Accuracy: 10.9%, Avg loss: 7.696352
#
# Epoch 72
# -------------------------------
# loss: 0.164841  [    0/60000]
# loss: 0.223673  [ 6400/60000]
# loss: 0.149553  [12800/60000]
# loss: 0.281147  [19200/60000]
# loss: 0.170750  [25600/60000]
# loss: 0.259075  [32000/60000]
# loss: 0.144703  [38400/60000]
# loss: 0.310885  [44800/60000]
# loss: 0.219015  [51200/60000]
# loss: 0.324356  [57600/60000]
# Test Error:
#  Accuracy: 10.9%, Avg loss: 7.716913
#
# Epoch 73
# -------------------------------
# loss: 0.162969  [    0/60000]
# loss: 0.222702  [ 6400/60000]
# loss: 0.148327  [12800/60000]
# loss: 0.279407  [19200/60000]
# loss: 0.169475  [25600/60000]
# loss: 0.257850  [32000/60000]
# loss: 0.143565  [38400/60000]
# loss: 0.309317  [44800/60000]
# loss: 0.216912  [51200/60000]
# loss: 0.322177  [57600/60000]
# Test Error:
#  Accuracy: 10.9%, Avg loss: 7.737234
#
# Epoch 74
# -------------------------------
# loss: 0.161196  [    0/60000]
# loss: 0.221698  [ 6400/60000]
# loss: 0.147150  [12800/60000]
# loss: 0.277732  [19200/60000]
# loss: 0.168216  [25600/60000]
# loss: 0.256641  [32000/60000]
# loss: 0.142432  [38400/60000]
# loss: 0.307824  [44800/60000]
# loss: 0.214888  [51200/60000]
# loss: 0.320013  [57600/60000]
# Test Error:
#  Accuracy: 10.8%, Avg loss: 7.757445
#
# Epoch 75
# -------------------------------
# loss: 0.159446  [    0/60000]
# loss: 0.220735  [ 6400/60000]
# loss: 0.145995  [12800/60000]
# loss: 0.276066  [19200/60000]
# loss: 0.166995  [25600/60000]
# loss: 0.255409  [32000/60000]
# loss: 0.141309  [38400/60000]
# loss: 0.306328  [44800/60000]
# loss: 0.212888  [51200/60000]
# loss: 0.317876  [57600/60000]
# Test Error:
#  Accuracy: 10.8%, Avg loss: 7.777622
#
# Epoch 76
# -------------------------------
# loss: 0.157724  [    0/60000]
# loss: 0.219740  [ 6400/60000]
# loss: 0.144861  [12800/60000]
# loss: 0.274399  [19200/60000]
# loss: 0.165788  [25600/60000]
# loss: 0.254243  [32000/60000]
# loss: 0.140198  [38400/60000]
# loss: 0.304833  [44800/60000]
# loss: 0.210942  [51200/60000]
# loss: 0.315760  [57600/60000]
# Test Error:
#  Accuracy: 10.9%, Avg loss: 7.797046
#
# Epoch 77
# -------------------------------
# loss: 0.156030  [    0/60000]
# loss: 0.218788  [ 6400/60000]
# loss: 0.143746  [12800/60000]
# loss: 0.272752  [19200/60000]
# loss: 0.164597  [25600/60000]
# loss: 0.253111  [32000/60000]
# loss: 0.139073  [38400/60000]
# loss: 0.303325  [44800/60000]
# loss: 0.209006  [51200/60000]
# loss: 0.313689  [57600/60000]
# Test Error:
#  Accuracy: 10.9%, Avg loss: 7.816739
#
# Epoch 78
# -------------------------------
# loss: 0.154392  [    0/60000]
# loss: 0.217856  [ 6400/60000]
# loss: 0.142654  [12800/60000]
# loss: 0.271148  [19200/60000]
# loss: 0.163461  [25600/60000]
# loss: 0.251986  [32000/60000]
# loss: 0.137960  [38400/60000]
# loss: 0.301827  [44800/60000]
# loss: 0.207101  [51200/60000]
# loss: 0.311674  [57600/60000]
# Test Error:
#  Accuracy: 10.8%, Avg loss: 7.836207
#
# Epoch 79
# -------------------------------
# loss: 0.152794  [    0/60000]
# loss: 0.216953  [ 6400/60000]
# loss: 0.141597  [12800/60000]
# loss: 0.269547  [19200/60000]
# loss: 0.162362  [25600/60000]
# loss: 0.250859  [32000/60000]
# loss: 0.136829  [38400/60000]
# loss: 0.300383  [44800/60000]
# loss: 0.205234  [51200/60000]
# loss: 0.309646  [57600/60000]
# Test Error:
#  Accuracy: 10.8%, Avg loss: 7.855257
#
# Epoch 80
# -------------------------------
# loss: 0.151249  [    0/60000]
# loss: 0.216105  [ 6400/60000]
# loss: 0.140556  [12800/60000]
# loss: 0.267945  [19200/60000]
# loss: 0.161281  [25600/60000]
# loss: 0.249707  [32000/60000]
# loss: 0.135706  [38400/60000]
# loss: 0.298958  [44800/60000]
# loss: 0.203432  [51200/60000]
# loss: 0.307621  [57600/60000]
# Test Error:
#  Accuracy: 10.8%, Avg loss: 7.874751
#
# Epoch 81
# -------------------------------
# loss: 0.149724  [    0/60000]
# loss: 0.215245  [ 6400/60000]
# loss: 0.139536  [12800/60000]
# loss: 0.266336  [19200/60000]
# loss: 0.160234  [25600/60000]
# loss: 0.248610  [32000/60000]
# loss: 0.134634  [38400/60000]
# loss: 0.297519  [44800/60000]
# loss: 0.201656  [51200/60000]
# loss: 0.305630  [57600/60000]
# Test Error:
#  Accuracy: 10.7%, Avg loss: 7.893634
#
# Epoch 82
# -------------------------------
# loss: 0.148229  [    0/60000]
# loss: 0.214385  [ 6400/60000]
# loss: 0.138527  [12800/60000]
# loss: 0.264706  [19200/60000]
# loss: 0.159204  [25600/60000]
# loss: 0.247591  [32000/60000]
# loss: 0.133566  [38400/60000]
# loss: 0.296009  [44800/60000]
# loss: 0.199910  [51200/60000]
# loss: 0.303681  [57600/60000]
# Test Error:
#  Accuracy: 10.7%, Avg loss: 7.912328
#
# Epoch 83
# -------------------------------
# loss: 0.146758  [    0/60000]
# loss: 0.213576  [ 6400/60000]
# loss: 0.137535  [12800/60000]
# loss: 0.263107  [19200/60000]
# loss: 0.158206  [25600/60000]
# loss: 0.246579  [32000/60000]
# loss: 0.132519  [38400/60000]
# loss: 0.294461  [44800/60000]
# loss: 0.198213  [51200/60000]
# loss: 0.301788  [57600/60000]
# Test Error:
#  Accuracy: 10.7%, Avg loss: 7.930714
#
# Epoch 84
# -------------------------------
# loss: 0.145326  [    0/60000]
# loss: 0.212796  [ 6400/60000]
# loss: 0.136570  [12800/60000]
# loss: 0.261532  [19200/60000]
# loss: 0.157266  [25600/60000]
# loss: 0.245547  [32000/60000]
# loss: 0.131473  [38400/60000]
# loss: 0.292958  [44800/60000]
# loss: 0.196536  [51200/60000]
# loss: 0.299901  [57600/60000]
# Test Error:
#  Accuracy: 10.7%, Avg loss: 7.948868
#
# Epoch 85
# -------------------------------
# loss: 0.143912  [    0/60000]
# loss: 0.212054  [ 6400/60000]
# loss: 0.135620  [12800/60000]
# loss: 0.259960  [19200/60000]
# loss: 0.156341  [25600/60000]
# loss: 0.244518  [32000/60000]
# loss: 0.130449  [38400/60000]
# loss: 0.291492  [44800/60000]
# loss: 0.194914  [51200/60000]
# loss: 0.298024  [57600/60000]
# Test Error:
#  Accuracy: 10.7%, Avg loss: 7.966735
#
# Epoch 86
# -------------------------------
# loss: 0.142519  [    0/60000]
# loss: 0.211310  [ 6400/60000]
# loss: 0.134688  [12800/60000]
# loss: 0.258409  [19200/60000]
# loss: 0.155430  [25600/60000]
# loss: 0.243500  [32000/60000]
# loss: 0.129439  [38400/60000]
# loss: 0.290010  [44800/60000]
# loss: 0.193321  [51200/60000]
# loss: 0.296202  [57600/60000]
# Test Error:
#  Accuracy: 10.7%, Avg loss: 7.984466
#
# Epoch 87
# -------------------------------
# loss: 0.141167  [    0/60000]
# loss: 0.210536  [ 6400/60000]
# loss: 0.133759  [12800/60000]
# loss: 0.256880  [19200/60000]
# loss: 0.154524  [25600/60000]
# loss: 0.242500  [32000/60000]
# loss: 0.128436  [38400/60000]
# loss: 0.288530  [44800/60000]
# loss: 0.191790  [51200/60000]
# loss: 0.294416  [57600/60000]
# Test Error:
#  Accuracy: 10.6%, Avg loss: 8.002326
#
# Epoch 88
# -------------------------------
# loss: 0.139845  [    0/60000]
# loss: 0.209800  [ 6400/60000]
# loss: 0.132848  [12800/60000]
# loss: 0.255369  [19200/60000]
# loss: 0.153638  [25600/60000]
# loss: 0.241515  [32000/60000]
# loss: 0.127444  [38400/60000]
# loss: 0.287057  [44800/60000]
# loss: 0.190292  [51200/60000]
# loss: 0.292710  [57600/60000]
# Test Error:
#  Accuracy: 10.6%, Avg loss: 8.019947
#
# Epoch 89
# -------------------------------
# loss: 0.138530  [    0/60000]
# loss: 0.209072  [ 6400/60000]
# loss: 0.131935  [12800/60000]
# loss: 0.253890  [19200/60000]
# loss: 0.152763  [25600/60000]
# loss: 0.240554  [32000/60000]
# loss: 0.126451  [38400/60000]
# loss: 0.285635  [44800/60000]
# loss: 0.188848  [51200/60000]
# loss: 0.291054  [57600/60000]
# Test Error:
#  Accuracy: 10.5%, Avg loss: 8.037183
#
# Epoch 90
# -------------------------------
# loss: 0.137251  [    0/60000]
# loss: 0.208321  [ 6400/60000]
# loss: 0.131006  [12800/60000]
# loss: 0.252418  [19200/60000]
# loss: 0.151905  [25600/60000]
# loss: 0.239605  [32000/60000]
# loss: 0.125471  [38400/60000]
# loss: 0.284205  [44800/60000]
# loss: 0.187442  [51200/60000]
# loss: 0.289417  [57600/60000]
# Test Error:
#  Accuracy: 10.5%, Avg loss: 8.054494
#
# Epoch 91
# -------------------------------
# loss: 0.136031  [    0/60000]
# loss: 0.207589  [ 6400/60000]
# loss: 0.130092  [12800/60000]
# loss: 0.250960  [19200/60000]
# loss: 0.151074  [25600/60000]
# loss: 0.238683  [32000/60000]
# loss: 0.124506  [38400/60000]
# loss: 0.282815  [44800/60000]
# loss: 0.186110  [51200/60000]
# loss: 0.287826  [57600/60000]
# Test Error:
#  Accuracy: 10.5%, Avg loss: 8.071539
#
# Epoch 92
# -------------------------------
# loss: 0.134824  [    0/60000]
# loss: 0.206862  [ 6400/60000]
# loss: 0.129195  [12800/60000]
# loss: 0.249505  [19200/60000]
# loss: 0.150227  [25600/60000]
# loss: 0.237762  [32000/60000]
# loss: 0.123547  [38400/60000]
# loss: 0.281443  [44800/60000]
# loss: 0.184818  [51200/60000]
# loss: 0.286252  [57600/60000]
# Test Error:
#  Accuracy: 10.5%, Avg loss: 8.088810
#
# Epoch 93
# -------------------------------
# loss: 0.133635  [    0/60000]
# loss: 0.206146  [ 6400/60000]
# loss: 0.128297  [12800/60000]
# loss: 0.248079  [19200/60000]
# loss: 0.149405  [25600/60000]
# loss: 0.236807  [32000/60000]
# loss: 0.122612  [38400/60000]
# loss: 0.280091  [44800/60000]
# loss: 0.183555  [51200/60000]
# loss: 0.284710  [57600/60000]
# Test Error:
#  Accuracy: 10.5%, Avg loss: 8.106192
#
# Epoch 94
# -------------------------------
# loss: 0.132488  [    0/60000]
# loss: 0.205432  [ 6400/60000]
# loss: 0.127428  [12800/60000]
# loss: 0.246685  [19200/60000]
# loss: 0.148596  [25600/60000]
# loss: 0.235843  [32000/60000]
# loss: 0.121707  [38400/60000]
# loss: 0.278748  [44800/60000]
# loss: 0.182313  [51200/60000]
# loss: 0.283188  [57600/60000]
# Test Error:
#  Accuracy: 10.5%, Avg loss: 8.123292
#
# Epoch 95
# -------------------------------
# loss: 0.131360  [    0/60000]
# loss: 0.204739  [ 6400/60000]
# loss: 0.126555  [12800/60000]
# loss: 0.245268  [19200/60000]
# loss: 0.147786  [25600/60000]
# loss: 0.234887  [32000/60000]
# loss: 0.120819  [38400/60000]
# loss: 0.277438  [44800/60000]
# loss: 0.181081  [51200/60000]
# loss: 0.281694  [57600/60000]
# Test Error:
#  Accuracy: 10.4%, Avg loss: 8.140217
#
# Epoch 96
# -------------------------------
# loss: 0.130261  [    0/60000]
# loss: 0.204075  [ 6400/60000]
# loss: 0.125688  [12800/60000]
# loss: 0.243888  [19200/60000]
# loss: 0.146995  [25600/60000]
# loss: 0.233922  [32000/60000]
# loss: 0.119926  [38400/60000]
# loss: 0.276089  [44800/60000]
# loss: 0.179887  [51200/60000]
# loss: 0.280229  [57600/60000]
# Test Error:
#  Accuracy: 10.4%, Avg loss: 8.157163
#
# Epoch 97
# -------------------------------
# loss: 0.129193  [    0/60000]
# loss: 0.203382  [ 6400/60000]
# loss: 0.124820  [12800/60000]
# loss: 0.242497  [19200/60000]
# loss: 0.146191  [25600/60000]
# loss: 0.232932  [32000/60000]
# loss: 0.118998  [38400/60000]
# loss: 0.274736  [44800/60000]
# loss: 0.178693  [51200/60000]
# loss: 0.278789  [57600/60000]
# Test Error:
#  Accuracy: 10.4%, Avg loss: 8.173938
#
# Epoch 98
# -------------------------------
# loss: 0.128142  [    0/60000]
# loss: 0.202694  [ 6400/60000]
# loss: 0.123959  [12800/60000]
# loss: 0.241104  [19200/60000]
# loss: 0.145413  [25600/60000]
# loss: 0.231959  [32000/60000]
# loss: 0.118079  [38400/60000]
# loss: 0.273360  [44800/60000]
# loss: 0.177492  [51200/60000]
# loss: 0.277378  [57600/60000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 8.190601
#
# Epoch 99
# -------------------------------
# loss: 0.127108  [    0/60000]
# loss: 0.202017  [ 6400/60000]
# loss: 0.123112  [12800/60000]
# loss: 0.239741  [19200/60000]
# loss: 0.144638  [25600/60000]
# loss: 0.230989  [32000/60000]
# loss: 0.117190  [38400/60000]
# loss: 0.271952  [44800/60000]
# loss: 0.176339  [51200/60000]
# loss: 0.276002  [57600/60000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 8.207270
#
# Epoch 100
# -------------------------------
# loss: 0.126101  [    0/60000]
# loss: 0.201358  [ 6400/60000]
# loss: 0.122280  [12800/60000]
# loss: 0.238378  [19200/60000]
# loss: 0.143873  [25600/60000]
# loss: 0.229988  [32000/60000]
# loss: 0.116308  [38400/60000]
# loss: 0.270560  [44800/60000]
# loss: 0.175232  [51200/60000]
# loss: 0.274627  [57600/60000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 8.223821
#
# Epoch 101
# -------------------------------
# loss: 0.125117  [    0/60000]
# loss: 0.200706  [ 6400/60000]
# loss: 0.121471  [12800/60000]
# loss: 0.237029  [19200/60000]
# loss: 0.143079  [25600/60000]
# loss: 0.229006  [32000/60000]
# loss: 0.115414  [38400/60000]
# loss: 0.269187  [44800/60000]
# loss: 0.174178  [51200/60000]
# loss: 0.273257  [57600/60000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 8.240022
#
# Epoch 102
# -------------------------------
# loss: 0.124125  [    0/60000]
# loss: 0.200082  [ 6400/60000]
# loss: 0.120674  [12800/60000]
# loss: 0.235672  [19200/60000]
# loss: 0.142277  [25600/60000]
# loss: 0.228009  [32000/60000]
# loss: 0.114515  [38400/60000]
# loss: 0.267847  [44800/60000]
# loss: 0.173163  [51200/60000]
# loss: 0.271920  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.256060
#
# Epoch 103
# -------------------------------
# loss: 0.123127  [    0/60000]
# loss: 0.199466  [ 6400/60000]
# loss: 0.119888  [12800/60000]
# loss: 0.234357  [19200/60000]
# loss: 0.141486  [25600/60000]
# loss: 0.227053  [32000/60000]
# loss: 0.113628  [38400/60000]
# loss: 0.266529  [44800/60000]
# loss: 0.172163  [51200/60000]
# loss: 0.270597  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.272159
#
# Epoch 104
# -------------------------------
# loss: 0.122145  [    0/60000]
# loss: 0.198843  [ 6400/60000]
# loss: 0.119091  [12800/60000]
# loss: 0.233058  [19200/60000]
# loss: 0.140690  [25600/60000]
# loss: 0.226084  [32000/60000]
# loss: 0.112743  [38400/60000]
# loss: 0.265223  [44800/60000]
# loss: 0.171203  [51200/60000]
# loss: 0.269312  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.288579
#
# Epoch 105
# -------------------------------
# loss: 0.121176  [    0/60000]
# loss: 0.198228  [ 6400/60000]
# loss: 0.118322  [12800/60000]
# loss: 0.231792  [19200/60000]
# loss: 0.139899  [25600/60000]
# loss: 0.225155  [32000/60000]
# loss: 0.111862  [38400/60000]
# loss: 0.263944  [44800/60000]
# loss: 0.170283  [51200/60000]
# loss: 0.268026  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.304872
#
# Epoch 106
# -------------------------------
# loss: 0.120210  [    0/60000]
# loss: 0.197656  [ 6400/60000]
# loss: 0.117561  [12800/60000]
# loss: 0.230556  [19200/60000]
# loss: 0.139112  [25600/60000]
# loss: 0.224234  [32000/60000]
# loss: 0.110994  [38400/60000]
# loss: 0.262681  [44800/60000]
# loss: 0.169410  [51200/60000]
# loss: 0.266758  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.321338
#
# Epoch 107
# -------------------------------
# loss: 0.119266  [    0/60000]
# loss: 0.197080  [ 6400/60000]
# loss: 0.116822  [12800/60000]
# loss: 0.229289  [19200/60000]
# loss: 0.138337  [25600/60000]
# loss: 0.223313  [32000/60000]
# loss: 0.110139  [38400/60000]
# loss: 0.261432  [44800/60000]
# loss: 0.168513  [51200/60000]
# loss: 0.265519  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.337559
#
# Epoch 108
# -------------------------------
# loss: 0.118339  [    0/60000]
# loss: 0.196495  [ 6400/60000]
# loss: 0.116097  [12800/60000]
# loss: 0.228023  [19200/60000]
# loss: 0.137603  [25600/60000]
# loss: 0.222436  [32000/60000]
# loss: 0.109284  [38400/60000]
# loss: 0.260200  [44800/60000]
# loss: 0.167642  [51200/60000]
# loss: 0.264290  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.353453
#
# Epoch 109
# -------------------------------
# loss: 0.117429  [    0/60000]
# loss: 0.195889  [ 6400/60000]
# loss: 0.115383  [12800/60000]
# loss: 0.226786  [19200/60000]
# loss: 0.136882  [25600/60000]
# loss: 0.221549  [32000/60000]
# loss: 0.108448  [38400/60000]
# loss: 0.258980  [44800/60000]
# loss: 0.166789  [51200/60000]
# loss: 0.263073  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.369276
#
# Epoch 110
# -------------------------------
# loss: 0.116528  [    0/60000]
# loss: 0.195311  [ 6400/60000]
# loss: 0.114669  [12800/60000]
# loss: 0.225573  [19200/60000]
# loss: 0.136162  [25600/60000]
# loss: 0.220644  [32000/60000]
# loss: 0.107621  [38400/60000]
# loss: 0.257777  [44800/60000]
# loss: 0.165921  [51200/60000]
# loss: 0.261908  [57600/60000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 8.384832
#
# Epoch 111
# -------------------------------
# loss: 0.115653  [    0/60000]
# loss: 0.194735  [ 6400/60000]
# loss: 0.113969  [12800/60000]
# loss: 0.224356  [19200/60000]
# loss: 0.135457  [25600/60000]
# loss: 0.219741  [32000/60000]
# loss: 0.106798  [38400/60000]
# loss: 0.256571  [44800/60000]
# loss: 0.165044  [51200/60000]
# loss: 0.260749  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.400278
#
# Epoch 112
# -------------------------------
# loss: 0.114795  [    0/60000]
# loss: 0.194146  [ 6400/60000]
# loss: 0.113281  [12800/60000]
# loss: 0.223163  [19200/60000]
# loss: 0.134741  [25600/60000]
# loss: 0.218857  [32000/60000]
# loss: 0.105970  [38400/60000]
# loss: 0.255368  [44800/60000]
# loss: 0.164178  [51200/60000]
# loss: 0.259608  [57600/60000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 8.415811
#
# Epoch 113
# -------------------------------
# loss: 0.113935  [    0/60000]
# loss: 0.193581  [ 6400/60000]
# loss: 0.112601  [12800/60000]
# loss: 0.221958  [19200/60000]
# loss: 0.134039  [25600/60000]
# loss: 0.217933  [32000/60000]
# loss: 0.105157  [38400/60000]
# loss: 0.254172  [44800/60000]
# loss: 0.163324  [51200/60000]
# loss: 0.258486  [57600/60000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 8.431235
#
# Epoch 114
# -------------------------------
# loss: 0.113087  [    0/60000]
# loss: 0.192999  [ 6400/60000]
# loss: 0.111937  [12800/60000]
# loss: 0.220792  [19200/60000]
# loss: 0.133348  [25600/60000]
# loss: 0.217016  [32000/60000]
# loss: 0.104348  [38400/60000]
# loss: 0.253025  [44800/60000]
# loss: 0.162484  [51200/60000]
# loss: 0.257358  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.446729
#
# Epoch 115
# -------------------------------
# loss: 0.112268  [    0/60000]
# loss: 0.192405  [ 6400/60000]
# loss: 0.111293  [12800/60000]
# loss: 0.219618  [19200/60000]
# loss: 0.132652  [25600/60000]
# loss: 0.216064  [32000/60000]
# loss: 0.103562  [38400/60000]
# loss: 0.251904  [44800/60000]
# loss: 0.161673  [51200/60000]
# loss: 0.256273  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.462109
#
# Epoch 116
# -------------------------------
# loss: 0.111460  [    0/60000]
# loss: 0.191804  [ 6400/60000]
# loss: 0.110655  [12800/60000]
# loss: 0.218430  [19200/60000]
# loss: 0.131954  [25600/60000]
# loss: 0.215122  [32000/60000]
# loss: 0.102781  [38400/60000]
# loss: 0.250786  [44800/60000]
# loss: 0.160893  [51200/60000]
# loss: 0.255211  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.477292
#
# Epoch 117
# -------------------------------
# loss: 0.110650  [    0/60000]
# loss: 0.191224  [ 6400/60000]
# loss: 0.110013  [12800/60000]
# loss: 0.217262  [19200/60000]
# loss: 0.131247  [25600/60000]
# loss: 0.214154  [32000/60000]
# loss: 0.102015  [38400/60000]
# loss: 0.249655  [44800/60000]
# loss: 0.160133  [51200/60000]
# loss: 0.254184  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.492564
#
# Epoch 118
# -------------------------------
# loss: 0.109859  [    0/60000]
# loss: 0.190635  [ 6400/60000]
# loss: 0.109365  [12800/60000]
# loss: 0.216091  [19200/60000]
# loss: 0.130551  [25600/60000]
# loss: 0.213188  [32000/60000]
# loss: 0.101275  [38400/60000]
# loss: 0.248568  [44800/60000]
# loss: 0.159382  [51200/60000]
# loss: 0.253153  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.507572
#
# Epoch 119
# -------------------------------
# loss: 0.109066  [    0/60000]
# loss: 0.190055  [ 6400/60000]
# loss: 0.108743  [12800/60000]
# loss: 0.214926  [19200/60000]
# loss: 0.129888  [25600/60000]
# loss: 0.212225  [32000/60000]
# loss: 0.100537  [38400/60000]
# loss: 0.247469  [44800/60000]
# loss: 0.158638  [51200/60000]
# loss: 0.252141  [57600/60000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 8.522564
#
# Epoch 120
# -------------------------------
# loss: 0.108294  [    0/60000]
# loss: 0.189455  [ 6400/60000]
# loss: 0.108139  [12800/60000]
# loss: 0.213767  [19200/60000]
# loss: 0.129226  [25600/60000]
# loss: 0.211275  [32000/60000]
# loss: 0.099809  [38400/60000]
# loss: 0.246352  [44800/60000]
# loss: 0.157920  [51200/60000]
# loss: 0.251146  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.537231
#
# Epoch 121
# -------------------------------
# loss: 0.107525  [    0/60000]
# loss: 0.188852  [ 6400/60000]
# loss: 0.107541  [12800/60000]
# loss: 0.212616  [19200/60000]
# loss: 0.128582  [25600/60000]
# loss: 0.210305  [32000/60000]
# loss: 0.099088  [38400/60000]
# loss: 0.245263  [44800/60000]
# loss: 0.157210  [51200/60000]
# loss: 0.250160  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.551959
#
# Epoch 122
# -------------------------------
# loss: 0.106723  [    0/60000]
# loss: 0.188251  [ 6400/60000]
# loss: 0.106948  [12800/60000]
# loss: 0.211478  [19200/60000]
# loss: 0.127937  [25600/60000]
# loss: 0.209380  [32000/60000]
# loss: 0.098377  [38400/60000]
# loss: 0.244180  [44800/60000]
# loss: 0.156549  [51200/60000]
# loss: 0.249205  [57600/60000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 8.566623
#
# Epoch 123
# -------------------------------
# ...
# loss: 0.176354  [19200/60000]
# loss: 0.106659  [25600/60000]
# loss: 0.175068  [32000/60000]
# loss: 0.076894  [38400/60000]
# loss: 0.208238  [44800/60000]
# loss: 0.136950  [51200/60000]
# loss: 0.220352  [57600/60000]
# Test Error:
#  Accuracy: 9.7%, Avg loss: 9.090730
#
# Epoch 161
# -------------------------------
# loss: 0.081155  [    0/60000]
# loss: 0.168405  [ 6400/60000]
# loss: 0.089738  [12800/60000]
# loss: 0.175589  [19200/60000]
# loss: 0.106191  [25600/60000]
# loss: 0.174232  [32000/60000]
# loss: 0.076460  [38400/60000]
# loss: 0.207358  [44800/60000]
# loss: 0.136501  [51200/60000]
# loss: 0.219694  [57600/60000]
# Test Error:
#  Accuracy: 9.7%, Avg loss: 9.103959
#
# Epoch 162
# -------------------------------
# loss: 0.080634  [    0/60000]
# loss: 0.167927  [ 6400/60000]
# loss: 0.089382  [12800/60000]
# loss: 0.174797  [19200/60000]
# loss: 0.105717  [25600/60000]
# loss: 0.173383  [32000/60000]
# loss: 0.076023  [38400/60000]
# loss: 0.206485  [44800/60000]
# loss: 0.136055  [51200/60000]
# loss: 0.219094  [57600/60000]
# Test Error:
#  Accuracy: 9.6%, Avg loss: 9.117782
#
# Epoch 163
# -------------------------------
# loss: 0.080115  [    0/60000]
# loss: 0.167464  [ 6400/60000]
# loss: 0.089034  [12800/60000]
# loss: 0.174009  [19200/60000]
# loss: 0.105234  [25600/60000]
# loss: 0.172549  [32000/60000]
# loss: 0.075592  [38400/60000]
# loss: 0.205638  [44800/60000]
# loss: 0.135615  [51200/60000]
# loss: 0.218494  [57600/60000]
# Test Error:
#  Accuracy: 9.6%, Avg loss: 9.131442
#
# Epoch 164
# -------------------------------
# loss: 0.079597  [    0/60000]
# loss: 0.166992  [ 6400/60000]
# loss: 0.088686  [12800/60000]
# loss: 0.173244  [19200/60000]
# loss: 0.104769  [25600/60000]
# loss: 0.171742  [32000/60000]
# loss: 0.075150  [38400/60000]
# loss: 0.204763  [44800/60000]
# loss: 0.135170  [51200/60000]
# loss: 0.217882  [57600/60000]
# Test Error:
#  Accuracy: 9.6%, Avg loss: 9.144928
#
# Epoch 165
# -------------------------------
# loss: 0.079094  [    0/60000]
# loss: 0.166504  [ 6400/60000]
# loss: 0.088352  [12800/60000]
# loss: 0.172495  [19200/60000]
# loss: 0.104308  [25600/60000]
# loss: 0.170936  [32000/60000]
# loss: 0.074720  [38400/60000]
# loss: 0.203865  [44800/60000]
# loss: 0.134721  [51200/60000]
# loss: 0.217249  [57600/60000]
# Test Error:
#  Accuracy: 9.6%, Avg loss: 9.158068
#
# Epoch 166
# -------------------------------
# loss: 0.078599  [    0/60000]
# loss: 0.166053  [ 6400/60000]
# loss: 0.088019  [12800/60000]
# loss: 0.171733  [19200/60000]
# loss: 0.103818  [25600/60000]
# loss: 0.170108  [32000/60000]
# loss: 0.074308  [38400/60000]
# loss: 0.202995  [44800/60000]
# loss: 0.134287  [51200/60000]
# loss: 0.216613  [57600/60000]
# Test Error:
#  Accuracy: 9.6%, Avg loss: 9.171413
#
# Epoch 167
# -------------------------------
# loss: 0.078121  [    0/60000]
# loss: 0.165588  [ 6400/60000]
# loss: 0.087699  [12800/60000]
# loss: 0.170991  [19200/60000]
# loss: 0.103352  [25600/60000]
# loss: 0.169297  [32000/60000]
# loss: 0.073892  [38400/60000]
# loss: 0.202115  [44800/60000]
# loss: 0.133870  [51200/60000]
# loss: 0.215994  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.184585
#
# Epoch 168
# -------------------------------
# loss: 0.077647  [    0/60000]
# loss: 0.165135  [ 6400/60000]
# loss: 0.087389  [12800/60000]
# loss: 0.170251  [19200/60000]
# loss: 0.102902  [25600/60000]
# loss: 0.168480  [32000/60000]
# loss: 0.073486  [38400/60000]
# loss: 0.201257  [44800/60000]
# loss: 0.133454  [51200/60000]
# loss: 0.215348  [57600/60000]
# Test Error:
#  Accuracy: 9.6%, Avg loss: 9.197863
#
# Epoch 169
# -------------------------------
# loss: 0.077183  [    0/60000]
# loss: 0.164685  [ 6400/60000]
# loss: 0.087087  [12800/60000]
# loss: 0.169493  [19200/60000]
# loss: 0.102458  [25600/60000]
# loss: 0.167667  [32000/60000]
# loss: 0.073088  [38400/60000]
# loss: 0.200391  [44800/60000]
# loss: 0.133036  [51200/60000]
# loss: 0.214735  [57600/60000]
# Test Error:
#  Accuracy: 9.6%, Avg loss: 9.210969
#
# Epoch 170
# -------------------------------
# loss: 0.076704  [    0/60000]
# loss: 0.164267  [ 6400/60000]
# loss: 0.086789  [12800/60000]
# loss: 0.168730  [19200/60000]
# loss: 0.102011  [25600/60000]
# loss: 0.166872  [32000/60000]
# loss: 0.072699  [38400/60000]
# loss: 0.199536  [44800/60000]
# loss: 0.132626  [51200/60000]
# loss: 0.214116  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.224044
#
# Epoch 171
# -------------------------------
# loss: 0.076249  [    0/60000]
# loss: 0.163836  [ 6400/60000]
# loss: 0.086487  [12800/60000]
# loss: 0.167961  [19200/60000]
# loss: 0.101543  [25600/60000]
# loss: 0.166050  [32000/60000]
# loss: 0.072325  [38400/60000]
# loss: 0.198693  [44800/60000]
# loss: 0.132193  [51200/60000]
# loss: 0.213495  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.237326
#
# Epoch 172
# -------------------------------
# loss: 0.075796  [    0/60000]
# loss: 0.163420  [ 6400/60000]
# loss: 0.086181  [12800/60000]
# loss: 0.167153  [19200/60000]
# loss: 0.101072  [25600/60000]
# loss: 0.165232  [32000/60000]
# loss: 0.071948  [38400/60000]
# loss: 0.197858  [44800/60000]
# loss: 0.131777  [51200/60000]
# loss: 0.212877  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.250296
#
# Epoch 173
# -------------------------------
# loss: 0.075344  [    0/60000]
# loss: 0.163003  [ 6400/60000]
# loss: 0.085888  [12800/60000]
# loss: 0.166367  [19200/60000]
# loss: 0.100604  [25600/60000]
# loss: 0.164416  [32000/60000]
# loss: 0.071583  [38400/60000]
# loss: 0.197040  [44800/60000]
# loss: 0.131350  [51200/60000]
# loss: 0.212272  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.263210
#
# Epoch 174
# -------------------------------
# loss: 0.074898  [    0/60000]
# loss: 0.162578  [ 6400/60000]
# loss: 0.085607  [12800/60000]
# loss: 0.165580  [19200/60000]
# loss: 0.100127  [25600/60000]
# loss: 0.163600  [32000/60000]
# loss: 0.071217  [38400/60000]
# loss: 0.196219  [44800/60000]
# loss: 0.130939  [51200/60000]
# loss: 0.211647  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.276472
#
# Epoch 175
# -------------------------------
# loss: 0.074442  [    0/60000]
# loss: 0.162166  [ 6400/60000]
# loss: 0.085310  [12800/60000]
# loss: 0.164830  [19200/60000]
# loss: 0.099642  [25600/60000]
# loss: 0.162824  [32000/60000]
# loss: 0.070851  [38400/60000]
# loss: 0.195429  [44800/60000]
# loss: 0.130508  [51200/60000]
# loss: 0.211030  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.289268
#
# Epoch 176
# -------------------------------
# loss: 0.073992  [    0/60000]
# loss: 0.161743  [ 6400/60000]
# loss: 0.085031  [12800/60000]
# loss: 0.164085  [19200/60000]
# loss: 0.099169  [25600/60000]
# loss: 0.162045  [32000/60000]
# loss: 0.070499  [38400/60000]
# loss: 0.194634  [44800/60000]
# loss: 0.130078  [51200/60000]
# loss: 0.210411  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.301803
#
# Epoch 177
# -------------------------------
# loss: 0.073557  [    0/60000]
# loss: 0.161300  [ 6400/60000]
# loss: 0.084771  [12800/60000]
# loss: 0.163340  [19200/60000]
# loss: 0.098702  [25600/60000]
# loss: 0.161250  [32000/60000]
# loss: 0.070144  [38400/60000]
# loss: 0.193822  [44800/60000]
# loss: 0.129667  [51200/60000]
# loss: 0.209792  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.314435
#
# Epoch 178
# -------------------------------
# loss: 0.073126  [    0/60000]
# loss: 0.160834  [ 6400/60000]
# loss: 0.084513  [12800/60000]
# loss: 0.162576  [19200/60000]
# loss: 0.098225  [25600/60000]
# loss: 0.160471  [32000/60000]
# loss: 0.069801  [38400/60000]
# loss: 0.193013  [44800/60000]
# loss: 0.129247  [51200/60000]
# loss: 0.209148  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.326974
#
# Epoch 179
# -------------------------------
# loss: 0.072676  [    0/60000]
# loss: 0.160397  [ 6400/60000]
# loss: 0.084254  [12800/60000]
# loss: 0.161821  [19200/60000]
# loss: 0.097757  [25600/60000]
# loss: 0.159715  [32000/60000]
# loss: 0.069463  [38400/60000]
# loss: 0.192221  [44800/60000]
# loss: 0.128809  [51200/60000]
# loss: 0.208552  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.339140
#
# Epoch 180
# -------------------------------
# loss: 0.072213  [    0/60000]
# loss: 0.159949  [ 6400/60000]
# loss: 0.083987  [12800/60000]
# loss: 0.161079  [19200/60000]
# loss: 0.097289  [25600/60000]
# loss: 0.158955  [32000/60000]
# loss: 0.069128  [38400/60000]
# loss: 0.191451  [44800/60000]
# loss: 0.128384  [51200/60000]
# loss: 0.207958  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.351607
#
# Epoch 181
# -------------------------------
# loss: 0.071758  [    0/60000]
# loss: 0.159523  [ 6400/60000]
# loss: 0.083724  [12800/60000]
# loss: 0.160330  [19200/60000]
# loss: 0.096832  [25600/60000]
# loss: 0.158204  [32000/60000]
# loss: 0.068808  [38400/60000]
# loss: 0.190688  [44800/60000]
# loss: 0.127961  [51200/60000]
# loss: 0.207366  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.364379
#
# Epoch 182
# -------------------------------
# loss: 0.071320  [    0/60000]
# loss: 0.159102  [ 6400/60000]
# loss: 0.083470  [12800/60000]
# loss: 0.159601  [19200/60000]
# loss: 0.096384  [25600/60000]
# loss: 0.157469  [32000/60000]
# loss: 0.068481  [38400/60000]
# loss: 0.189927  [44800/60000]
# loss: 0.127532  [51200/60000]
# loss: 0.206775  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.377277
#
# Epoch 183
# -------------------------------
# loss: 0.070876  [    0/60000]
# loss: 0.158688  [ 6400/60000]
# loss: 0.083209  [12800/60000]
# loss: 0.158892  [19200/60000]
# loss: 0.095942  [25600/60000]
# loss: 0.156732  [32000/60000]
# loss: 0.068157  [38400/60000]
# loss: 0.189163  [44800/60000]
# loss: 0.127127  [51200/60000]
# loss: 0.206200  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.390197
#
# Epoch 184
# -------------------------------
# loss: 0.070436  [    0/60000]
# loss: 0.158249  [ 6400/60000]
# loss: 0.082962  [12800/60000]
# loss: 0.158211  [19200/60000]
# loss: 0.095521  [25600/60000]
# loss: 0.155998  [32000/60000]
# loss: 0.067837  [38400/60000]
# loss: 0.188417  [44800/60000]
# loss: 0.126729  [51200/60000]
# loss: 0.205599  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.403061
#
# Epoch 185
# -------------------------------
# loss: 0.070014  [    0/60000]
# loss: 0.157821  [ 6400/60000]
# loss: 0.082714  [12800/60000]
# loss: 0.157486  [19200/60000]
# loss: 0.095098  [25600/60000]
# loss: 0.155282  [32000/60000]
# loss: 0.067522  [38400/60000]
# loss: 0.187648  [44800/60000]
# loss: 0.126324  [51200/60000]
# loss: 0.205021  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.415894
#
# Epoch 186
# -------------------------------
# loss: 0.069586  [    0/60000]
# loss: 0.157392  [ 6400/60000]
# loss: 0.082468  [12800/60000]
# loss: 0.156783  [19200/60000]
# loss: 0.094687  [25600/60000]
# loss: 0.154559  [32000/60000]
# loss: 0.067207  [38400/60000]
# loss: 0.186886  [44800/60000]
# loss: 0.125932  [51200/60000]
# loss: 0.204437  [57600/60000]
# Test Error:
#  Accuracy: 9.5%, Avg loss: 9.429143
#
# Epoch 187
# -------------------------------
# loss: 0.069167  [    0/60000]
# loss: 0.156974  [ 6400/60000]
# loss: 0.082226  [12800/60000]
# loss: 0.156065  [19200/60000]
# loss: 0.094265  [25600/60000]
# loss: 0.153829  [32000/60000]
# loss: 0.066898  [38400/60000]
# loss: 0.186137  [44800/60000]
# loss: 0.125547  [51200/60000]
# loss: 0.203841  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.441787
#
# Epoch 188
# -------------------------------
# loss: 0.068734  [    0/60000]
# loss: 0.156559  [ 6400/60000]
# loss: 0.081980  [12800/60000]
# loss: 0.155344  [19200/60000]
# loss: 0.093850  [25600/60000]
# loss: 0.153114  [32000/60000]
# loss: 0.066594  [38400/60000]
# loss: 0.185393  [44800/60000]
# loss: 0.125163  [51200/60000]
# loss: 0.203221  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.454339
#
# Epoch 189
# -------------------------------
# loss: 0.068308  [    0/60000]
# loss: 0.156135  [ 6400/60000]
# loss: 0.081742  [12800/60000]
# loss: 0.154630  [19200/60000]
# loss: 0.093442  [25600/60000]
# loss: 0.152408  [32000/60000]
# loss: 0.066293  [38400/60000]
# loss: 0.184653  [44800/60000]
# loss: 0.124803  [51200/60000]
# loss: 0.202625  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.466738
#
# Epoch 190
# -------------------------------
# loss: 0.067886  [    0/60000]
# loss: 0.155716  [ 6400/60000]
# loss: 0.081516  [12800/60000]
# loss: 0.153898  [19200/60000]
# loss: 0.093038  [25600/60000]
# loss: 0.151694  [32000/60000]
# loss: 0.065989  [38400/60000]
# loss: 0.183919  [44800/60000]
# loss: 0.124450  [51200/60000]
# loss: 0.202019  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.479073
#
# Epoch 191
# -------------------------------
# loss: 0.067471  [    0/60000]
# loss: 0.155301  [ 6400/60000]
# loss: 0.081282  [12800/60000]
# loss: 0.153187  [19200/60000]
# loss: 0.092634  [25600/60000]
# loss: 0.150965  [32000/60000]
# loss: 0.065687  [38400/60000]
# loss: 0.183188  [44800/60000]
# loss: 0.124074  [51200/60000]
# loss: 0.201432  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.491614
#
# Epoch 192
# -------------------------------
# loss: 0.067052  [    0/60000]
# loss: 0.154900  [ 6400/60000]
# loss: 0.081061  [12800/60000]
# loss: 0.152468  [19200/60000]
# loss: 0.092222  [25600/60000]
# loss: 0.150228  [32000/60000]
# loss: 0.065388  [38400/60000]
# loss: 0.182438  [44800/60000]
# loss: 0.123701  [51200/60000]
# loss: 0.200857  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.504257
#
# Epoch 193
# -------------------------------
# loss: 0.066629  [    0/60000]
# loss: 0.154476  [ 6400/60000]
# loss: 0.080837  [12800/60000]
# loss: 0.151745  [19200/60000]
# loss: 0.091816  [25600/60000]
# loss: 0.149503  [32000/60000]
# loss: 0.065096  [38400/60000]
# loss: 0.181719  [44800/60000]
# loss: 0.123342  [51200/60000]
# loss: 0.200261  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.516776
#
# Epoch 194
# -------------------------------
# loss: 0.066223  [    0/60000]
# loss: 0.154064  [ 6400/60000]
# loss: 0.080628  [12800/60000]
# loss: 0.151023  [19200/60000]
# loss: 0.091419  [25600/60000]
# loss: 0.148775  [32000/60000]
# loss: 0.064812  [38400/60000]
# loss: 0.180986  [44800/60000]
# loss: 0.122984  [51200/60000]
# loss: 0.199671  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.529131
#
# Epoch 195
# -------------------------------
# loss: 0.065823  [    0/60000]
# loss: 0.153657  [ 6400/60000]
# loss: 0.080419  [12800/60000]
# loss: 0.150301  [19200/60000]
# loss: 0.091003  [25600/60000]
# loss: 0.148054  [32000/60000]
# loss: 0.064524  [38400/60000]
# loss: 0.180238  [44800/60000]
# loss: 0.122645  [51200/60000]
# loss: 0.199090  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.541669
#
# Epoch 196
# -------------------------------
# loss: 0.065423  [    0/60000]
# loss: 0.153267  [ 6400/60000]
# loss: 0.080204  [12800/60000]
# loss: 0.149588  [19200/60000]
# loss: 0.090587  [25600/60000]
# loss: 0.147354  [32000/60000]
# loss: 0.064241  [38400/60000]
# loss: 0.179489  [44800/60000]
# loss: 0.122295  [51200/60000]
# loss: 0.198515  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.553994
#
# Epoch 197
# -------------------------------
# loss: 0.065024  [    0/60000]
# loss: 0.152866  [ 6400/60000]
# loss: 0.079995  [12800/60000]
# loss: 0.148831  [19200/60000]
# loss: 0.090182  [25600/60000]
# loss: 0.146607  [32000/60000]
# loss: 0.063964  [38400/60000]
# loss: 0.178774  [44800/60000]
# loss: 0.121953  [51200/60000]
# loss: 0.197944  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.566161
#
# Epoch 198
# -------------------------------
# loss: 0.064631  [    0/60000]
# loss: 0.152475  [ 6400/60000]
# loss: 0.079778  [12800/60000]
# loss: 0.148116  [19200/60000]
# loss: 0.089773  [25600/60000]
# loss: 0.145892  [32000/60000]
# loss: 0.063683  [38400/60000]
# loss: 0.178042  [44800/60000]
# loss: 0.121608  [51200/60000]
# loss: 0.197383  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.578246
#
# Epoch 199
# -------------------------------
# loss: 0.064242  [    0/60000]
# loss: 0.152050  [ 6400/60000]
# loss: 0.079563  [12800/60000]
# loss: 0.147397  [19200/60000]
# loss: 0.089373  [25600/60000]
# loss: 0.145177  [32000/60000]
# loss: 0.063410  [38400/60000]
# loss: 0.177333  [44800/60000]
# loss: 0.121272  [51200/60000]
# loss: 0.196812  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.590160
#
# Epoch 200
# -------------------------------
# loss: 0.063862  [    0/60000]
# loss: 0.151655  [ 6400/60000]
# loss: 0.079351  [12800/60000]
# loss: 0.146671  [19200/60000]
# loss: 0.088970  [25600/60000]
# loss: 0.144454  [32000/60000]
# loss: 0.063140  [38400/60000]
# loss: 0.176600  [44800/60000]
# loss: 0.120923  [51200/60000]
# loss: 0.196239  [57600/60000]
# Test Error:
#  Accuracy: 9.4%, Avg loss: 9.602305
#
# Done!

# %% [markdown]
# # New Section
